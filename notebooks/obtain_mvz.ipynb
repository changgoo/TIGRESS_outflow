# %%
# %load obtain_mvz.py
import yt
from yt import derived_field
from yt.units.unit_object import Unit
from yt.units import kpc, pc, kboltz, mh
import numpy as np
import sys
import matplotlib.pyplot as plt
from math import *

import cooling
cf=cooling.coolftn()

#def _temp(field, data):
#    return  (mh*data['gas',"pressure"]/data['gas',"density"]/kboltz)

def _T1(field, data):
        return data["gas","pressure"]/data["gas","density"]*mh/kboltz

def _mu(field, data):
        T1=data["gas","T1"].d
        temp=cf.get_temp(T1)
        return temp/T1

def _temperature(field,data):
        return data["gas","T1"]*data["gas","mu"]
    
yt.add_field(("gas", "T1"), function=_T1, units='K')
yt.add_field(("gas", "mu"), function=_mu, units='')
yt.add_field(("gas", "temperature"), function=_temperature, units='K')


unit_base={"length_unit": (1.0,"pc"),
           "time_unit": (1.0,"s*pc/km"),
           "mass_unit": (2.38858753789e-24,"g/cm**3*pc**3"),
           "velocity_unit": (1.0,"km/s"),
           "magnetic_unit": (5.4786746797e-07,"gauss")}

tfin = 512.
tini = 500.
time = tini
while time<=tfin:
    num = int(time)
    filename =  '/tigress/changgoo/MHD_4pc_new/id0/MHD_4pc_new.0' + str(num) + '.vtk'
    outfile_warm  =  '/tigress/changgoo/MHD_4pc_new/MVZ/warm/MHD_4pc_new_mvz.0' + str(num)
    outfile_hot  =  '/tigress/changgoo/MHD_4pc_new/MVZ/hot/MHD_4pc_new_mvz.0' + str(num)
    outfile_int  =  '/tigress/changgoo/MHD_4pc_new/MVZ/int/MHD_4pc_new_mvz.0' + str(num)
    ds = yt.load(filename, units_override=unit_base)
    data = ds.all_data()

    cut_warm = data.cut_region(['(obj["temperature"]<=2.e4) & (obj["temperature"]>5050)']) 
    cut_int  = data.cut_region(['(obj["temperature"]>2.e4) & (obj["temperature"]<0.5e6)']) 
    cut_hot  = data.cut_region(['(obj["temperature"]>=0.5e6)']) 

    pdf_warm = yt.create_profile(cut_warm,['velocity_z','z'],fields='cell_mass',
                       extrema={'velocity_z':(-200,200),'z':(-3584,3584)},
                       n_bins=(400,1792),logs={'velocity_z':False,'z':False},
                       weight_field=None,fractional=False, units={'velocity_z':"km/s", 'z':'pc'})

    pdf_int = yt.create_profile(cut_int,['velocity_z','z'],fields='cell_mass',
                       extrema={'velocity_z':(-500,500),'z':(-3584,3584)},
                       n_bins=(400,1792),logs={'velocity_z':False,'z':False},
                       weight_field=None,fractional=False, units={'velocity_z':"km/s", 'z':'pc'})


    pdf_hot = yt.create_profile(cut_hot,['velocity_z','z'],fields='cell_mass',
                       extrema={'velocity_z':(-500,500),'z':(-3584,3584)},
                       n_bins=(400,1792),logs={'velocity_z':False,'z':False},
                       weight_field=None,fractional=False, units={'velocity_z':"km/s", 'z':'pc'})

    pdf_warm.save_as_dataset(outfile_warm)
    pdf_int.save_as_dataset(outfile_int)
    pdf_hot.save_as_dataset(outfile_hot)
    time = time + 1.
# Out:
# /tigress/changgoo/miniconda3/lib/python3.7/site-packages/yt/fields/local_fields.py:46: UserWarning: Because 'sampling_type' not specified, yt will assume a cell 'sampling_type'
#   warnings.warn("Because 'sampling_type' not specified, yt will "
# yt : [INFO     ] 2019-04-15 15:55:18,078 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2019-04-15 15:55:18,499 Overriding code units: Use this option only if you know that the dataset doesn't define the units correctly or at all.
# yt : [INFO     ] 2019-04-15 15:55:18,499 Overriding length_unit: 1 pc.
# yt : [INFO     ] 2019-04-15 15:55:18,500 Overriding time_unit: 1 s*pc/km.
# yt : [INFO     ] 2019-04-15 15:55:18,501 Overriding mass_unit: 2.38859e-24 g/cm**3*pc**3.
# yt : [INFO     ] 2019-04-15 15:55:18,502 Overriding velocity_unit: 1 km/s.
# yt : [INFO     ] 2019-04-15 15:55:18,503 Overriding magnetic_unit: 5.47867e-07 gauss.
# yt : [INFO     ] 2019-04-15 15:55:18,519 Parameters: current_time              = 499.0003
# yt : [INFO     ] 2019-04-15 15:55:18,520 Parameters: domain_dimensions         = [ 256  256 1792]
# yt : [INFO     ] 2019-04-15 15:55:18,520 Parameters: domain_left_edge          = [ -512.  -512. -3584.]
# yt : [INFO     ] 2019-04-15 15:55:18,520 Parameters: domain_right_edge         = [ 512.  512. 3584.]
# yt : [INFO     ] 2019-04-15 15:55:18,521 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2019-04-15 15:58:11,140 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/warm/MHD_4pc_new_mvz.0500.h5.
# yt : [INFO     ] 2019-04-15 15:58:11,222 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/int/MHD_4pc_new_mvz.0500.h5.
# yt : [INFO     ] 2019-04-15 15:58:11,277 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/hot/MHD_4pc_new_mvz.0500.h5.
# yt : [INFO     ] 2019-04-15 15:58:11,579 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2019-04-15 15:58:11,630 Overriding code units: Use this option only if you know that the dataset doesn't define the units correctly or at all.
# yt : [INFO     ] 2019-04-15 15:58:11,631 Overriding length_unit: 1 pc.
# yt : [INFO     ] 2019-04-15 15:58:11,631 Overriding time_unit: 1 s*pc/km.
# yt : [INFO     ] 2019-04-15 15:58:11,632 Overriding mass_unit: 2.38859e-24 g/cm**3*pc**3.
# yt : [INFO     ] 2019-04-15 15:58:11,633 Overriding velocity_unit: 1 km/s.
# yt : [INFO     ] 2019-04-15 15:58:11,634 Overriding magnetic_unit: 5.47867e-07 gauss.
# yt : [INFO     ] 2019-04-15 15:58:11,643 Parameters: current_time              = 500.0
# yt : [INFO     ] 2019-04-15 15:58:11,643 Parameters: domain_dimensions         = [ 256  256 1792]
# yt : [INFO     ] 2019-04-15 15:58:11,644 Parameters: domain_left_edge          = [ -512.  -512. -3584.]
# yt : [INFO     ] 2019-04-15 15:58:11,644 Parameters: domain_right_edge         = [ 512.  512. 3584.]
# yt : [INFO     ] 2019-04-15 15:58:11,646 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2019-04-15 16:01:04,562 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/warm/MHD_4pc_new_mvz.0501.h5.
# yt : [INFO     ] 2019-04-15 16:01:04,641 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/int/MHD_4pc_new_mvz.0501.h5.
# yt : [INFO     ] 2019-04-15 16:01:04,719 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/hot/MHD_4pc_new_mvz.0501.h5.
# yt : [INFO     ] 2019-04-15 16:01:04,958 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2019-04-15 16:01:05,012 Overriding code units: Use this option only if you know that the dataset doesn't define the units correctly or at all.
# yt : [INFO     ] 2019-04-15 16:01:05,012 Overriding length_unit: 1 pc.
# yt : [INFO     ] 2019-04-15 16:01:05,013 Overriding time_unit: 1 s*pc/km.
# yt : [INFO     ] 2019-04-15 16:01:05,014 Overriding mass_unit: 2.38859e-24 g/cm**3*pc**3.
# yt : [INFO     ] 2019-04-15 16:01:05,015 Overriding velocity_unit: 1 km/s.
# yt : [INFO     ] 2019-04-15 16:01:05,015 Overriding magnetic_unit: 5.47867e-07 gauss.
# yt : [INFO     ] 2019-04-15 16:01:05,025 Parameters: current_time              = 501.0005
# yt : [INFO     ] 2019-04-15 16:01:05,026 Parameters: domain_dimensions         = [ 256  256 1792]
# yt : [INFO     ] 2019-04-15 16:01:05,027 Parameters: domain_left_edge          = [ -512.  -512. -3584.]
# yt : [INFO     ] 2019-04-15 16:01:05,028 Parameters: domain_right_edge         = [ 512.  512. 3584.]
# yt : [INFO     ] 2019-04-15 16:01:05,028 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2019-04-15 16:04:00,748 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/warm/MHD_4pc_new_mvz.0502.h5.
# yt : [INFO     ] 2019-04-15 16:04:00,799 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/int/MHD_4pc_new_mvz.0502.h5.
# yt : [INFO     ] 2019-04-15 16:04:00,875 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/hot/MHD_4pc_new_mvz.0502.h5.
# yt : [INFO     ] 2019-04-15 16:04:01,115 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2019-04-15 16:04:01,162 Overriding code units: Use this option only if you know that the dataset doesn't define the units correctly or at all.
# yt : [INFO     ] 2019-04-15 16:04:01,162 Overriding length_unit: 1 pc.
# yt : [INFO     ] 2019-04-15 16:04:01,163 Overriding time_unit: 1 s*pc/km.
# yt : [INFO     ] 2019-04-15 16:04:01,164 Overriding mass_unit: 2.38859e-24 g/cm**3*pc**3.
# yt : [INFO     ] 2019-04-15 16:04:01,164 Overriding velocity_unit: 1 km/s.
# yt : [INFO     ] 2019-04-15 16:04:01,165 Overriding magnetic_unit: 5.47867e-07 gauss.
# yt : [INFO     ] 2019-04-15 16:04:01,174 Parameters: current_time              = 502.0002
# yt : [INFO     ] 2019-04-15 16:04:01,174 Parameters: domain_dimensions         = [ 256  256 1792]
# yt : [INFO     ] 2019-04-15 16:04:01,174 Parameters: domain_left_edge          = [ -512.  -512. -3584.]
# yt : [INFO     ] 2019-04-15 16:04:01,175 Parameters: domain_right_edge         = [ 512.  512. 3584.]
# yt : [INFO     ] 2019-04-15 16:04:01,175 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2019-04-15 16:06:52,064 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/warm/MHD_4pc_new_mvz.0503.h5.
# yt : [INFO     ] 2019-04-15 16:06:52,145 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/int/MHD_4pc_new_mvz.0503.h5.
# yt : [INFO     ] 2019-04-15 16:06:52,221 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/hot/MHD_4pc_new_mvz.0503.h5.
# yt : [INFO     ] 2019-04-15 16:06:52,544 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2019-04-15 16:06:52,655 Overriding code units: Use this option only if you know that the dataset doesn't define the units correctly or at all.
# yt : [INFO     ] 2019-04-15 16:06:52,656 Overriding length_unit: 1 pc.
# yt : [INFO     ] 2019-04-15 16:06:52,656 Overriding time_unit: 1 s*pc/km.
# yt : [INFO     ] 2019-04-15 16:06:52,657 Overriding mass_unit: 2.38859e-24 g/cm**3*pc**3.
# yt : [INFO     ] 2019-04-15 16:06:52,658 Overriding velocity_unit: 1 km/s.
# yt : [INFO     ] 2019-04-15 16:06:52,658 Overriding magnetic_unit: 5.47867e-07 gauss.
# yt : [INFO     ] 2019-04-15 16:06:52,667 Parameters: current_time              = 503.0004
# yt : [INFO     ] 2019-04-15 16:06:52,667 Parameters: domain_dimensions         = [ 256  256 1792]
# yt : [INFO     ] 2019-04-15 16:06:52,668 Parameters: domain_left_edge          = [ -512.  -512. -3584.]
# yt : [INFO     ] 2019-04-15 16:06:52,668 Parameters: domain_right_edge         = [ 512.  512. 3584.]
# yt : [INFO     ] 2019-04-15 16:06:52,669 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2019-04-15 16:09:47,607 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/warm/MHD_4pc_new_mvz.0504.h5.
# yt : [INFO     ] 2019-04-15 16:09:47,725 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/int/MHD_4pc_new_mvz.0504.h5.
# yt : [INFO     ] 2019-04-15 16:09:47,834 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/hot/MHD_4pc_new_mvz.0504.h5.
# yt : [INFO     ] 2019-04-15 16:09:48,098 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2019-04-15 16:09:48,161 Overriding code units: Use this option only if you know that the dataset doesn't define the units correctly or at all.
# yt : [INFO     ] 2019-04-15 16:09:48,161 Overriding length_unit: 1 pc.
# yt : [INFO     ] 2019-04-15 16:09:48,162 Overriding time_unit: 1 s*pc/km.
# yt : [INFO     ] 2019-04-15 16:09:48,163 Overriding mass_unit: 2.38859e-24 g/cm**3*pc**3.
# yt : [INFO     ] 2019-04-15 16:09:48,163 Overriding velocity_unit: 1 km/s.
# yt : [INFO     ] 2019-04-15 16:09:48,164 Overriding magnetic_unit: 5.47867e-07 gauss.
# yt : [INFO     ] 2019-04-15 16:09:48,173 Parameters: current_time              = 504.0002
# yt : [INFO     ] 2019-04-15 16:09:48,173 Parameters: domain_dimensions         = [ 256  256 1792]
# yt : [INFO     ] 2019-04-15 16:09:48,173 Parameters: domain_left_edge          = [ -512.  -512. -3584.]
# yt : [INFO     ] 2019-04-15 16:09:48,174 Parameters: domain_right_edge         = [ 512.  512. 3584.]
# yt : [INFO     ] 2019-04-15 16:09:48,174 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2019-04-15 16:12:43,543 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/warm/MHD_4pc_new_mvz.0505.h5.
# yt : [INFO     ] 2019-04-15 16:12:43,635 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/int/MHD_4pc_new_mvz.0505.h5.
# yt : [INFO     ] 2019-04-15 16:12:43,767 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/hot/MHD_4pc_new_mvz.0505.h5.
# yt : [INFO     ] 2019-04-15 16:12:44,100 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2019-04-15 16:12:44,266 Overriding code units: Use this option only if you know that the dataset doesn't define the units correctly or at all.
# yt : [INFO     ] 2019-04-15 16:12:44,267 Overriding length_unit: 1 pc.
# yt : [INFO     ] 2019-04-15 16:12:44,268 Overriding time_unit: 1 s*pc/km.
# yt : [INFO     ] 2019-04-15 16:12:44,268 Overriding mass_unit: 2.38859e-24 g/cm**3*pc**3.
# yt : [INFO     ] 2019-04-15 16:12:44,269 Overriding velocity_unit: 1 km/s.
# yt : [INFO     ] 2019-04-15 16:12:44,270 Overriding magnetic_unit: 5.47867e-07 gauss.
# yt : [INFO     ] 2019-04-15 16:12:44,280 Parameters: current_time              = 505.0008
# yt : [INFO     ] 2019-04-15 16:12:44,280 Parameters: domain_dimensions         = [ 256  256 1792]
# yt : [INFO     ] 2019-04-15 16:12:44,281 Parameters: domain_left_edge          = [ -512.  -512. -3584.]
# yt : [INFO     ] 2019-04-15 16:12:44,282 Parameters: domain_right_edge         = [ 512.  512. 3584.]
# yt : [INFO     ] 2019-04-15 16:12:44,282 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2019-04-15 16:15:51,978 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/warm/MHD_4pc_new_mvz.0506.h5.
# yt : [INFO     ] 2019-04-15 16:15:52,029 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/int/MHD_4pc_new_mvz.0506.h5.
# yt : [INFO     ] 2019-04-15 16:15:52,091 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/hot/MHD_4pc_new_mvz.0506.h5.
# yt : [INFO     ] 2019-04-15 16:15:52,347 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2019-04-15 16:15:52,600 Overriding code units: Use this option only if you know that the dataset doesn't define the units correctly or at all.
# yt : [INFO     ] 2019-04-15 16:15:52,601 Overriding length_unit: 1 pc.
# yt : [INFO     ] 2019-04-15 16:15:52,601 Overriding time_unit: 1 s*pc/km.
# yt : [INFO     ] 2019-04-15 16:15:52,602 Overriding mass_unit: 2.38859e-24 g/cm**3*pc**3.
# yt : [INFO     ] 2019-04-15 16:15:52,603 Overriding velocity_unit: 1 km/s.
# yt : [INFO     ] 2019-04-15 16:15:52,604 Overriding magnetic_unit: 5.47867e-07 gauss.
# yt : [INFO     ] 2019-04-15 16:15:52,613 Parameters: current_time              = 506.0003
# yt : [INFO     ] 2019-04-15 16:15:52,613 Parameters: domain_dimensions         = [ 256  256 1792]
# yt : [INFO     ] 2019-04-15 16:15:52,614 Parameters: domain_left_edge          = [ -512.  -512. -3584.]
# yt : [INFO     ] 2019-04-15 16:15:52,615 Parameters: domain_right_edge         = [ 512.  512. 3584.]
# yt : [INFO     ] 2019-04-15 16:15:52,616 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2019-04-15 16:19:03,822 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/warm/MHD_4pc_new_mvz.0507.h5.
# yt : [INFO     ] 2019-04-15 16:19:03,873 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/int/MHD_4pc_new_mvz.0507.h5.
# yt : [INFO     ] 2019-04-15 16:19:03,953 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/hot/MHD_4pc_new_mvz.0507.h5.
# yt : [INFO     ] 2019-04-15 16:19:04,208 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2019-04-15 16:19:04,461 Overriding code units: Use this option only if you know that the dataset doesn't define the units correctly or at all.
# yt : [INFO     ] 2019-04-15 16:19:04,461 Overriding length_unit: 1 pc.
# yt : [INFO     ] 2019-04-15 16:19:04,462 Overriding time_unit: 1 s*pc/km.
# yt : [INFO     ] 2019-04-15 16:19:04,463 Overriding mass_unit: 2.38859e-24 g/cm**3*pc**3.
# yt : [INFO     ] 2019-04-15 16:19:04,463 Overriding velocity_unit: 1 km/s.
# yt : [INFO     ] 2019-04-15 16:19:04,464 Overriding magnetic_unit: 5.47867e-07 gauss.
# yt : [INFO     ] 2019-04-15 16:19:04,473 Parameters: current_time              = 507.0007
# yt : [INFO     ] 2019-04-15 16:19:04,473 Parameters: domain_dimensions         = [ 256  256 1792]
# yt : [INFO     ] 2019-04-15 16:19:04,474 Parameters: domain_left_edge          = [ -512.  -512. -3584.]
# yt : [INFO     ] 2019-04-15 16:19:04,474 Parameters: domain_right_edge         = [ 512.  512. 3584.]
# yt : [INFO     ] 2019-04-15 16:19:04,475 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2019-04-15 16:22:17,457 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/warm/MHD_4pc_new_mvz.0508.h5.
# yt : [INFO     ] 2019-04-15 16:22:17,509 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/int/MHD_4pc_new_mvz.0508.h5.
# yt : [INFO     ] 2019-04-15 16:22:17,556 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/hot/MHD_4pc_new_mvz.0508.h5.
# yt : [INFO     ] 2019-04-15 16:22:17,804 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2019-04-15 16:22:18,049 Overriding code units: Use this option only if you know that the dataset doesn't define the units correctly or at all.
# yt : [INFO     ] 2019-04-15 16:22:18,050 Overriding length_unit: 1 pc.
# yt : [INFO     ] 2019-04-15 16:22:18,051 Overriding time_unit: 1 s*pc/km.
# yt : [INFO     ] 2019-04-15 16:22:18,052 Overriding mass_unit: 2.38859e-24 g/cm**3*pc**3.
# yt : [INFO     ] 2019-04-15 16:22:18,053 Overriding velocity_unit: 1 km/s.
# yt : [INFO     ] 2019-04-15 16:22:18,054 Overriding magnetic_unit: 5.47867e-07 gauss.
# yt : [INFO     ] 2019-04-15 16:22:18,064 Parameters: current_time              = 508.0001
# yt : [INFO     ] 2019-04-15 16:22:18,065 Parameters: domain_dimensions         = [ 256  256 1792]
# yt : [INFO     ] 2019-04-15 16:22:18,066 Parameters: domain_left_edge          = [ -512.  -512. -3584.]
# yt : [INFO     ] 2019-04-15 16:22:18,067 Parameters: domain_right_edge         = [ 512.  512. 3584.]
# yt : [INFO     ] 2019-04-15 16:22:18,068 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2019-04-15 16:25:25,272 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/warm/MHD_4pc_new_mvz.0509.h5.
# yt : [INFO     ] 2019-04-15 16:25:25,322 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/int/MHD_4pc_new_mvz.0509.h5.
# yt : [INFO     ] 2019-04-15 16:25:25,394 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/hot/MHD_4pc_new_mvz.0509.h5.
# yt : [INFO     ] 2019-04-15 16:25:25,682 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2019-04-15 16:25:25,970 Overriding code units: Use this option only if you know that the dataset doesn't define the units correctly or at all.
# yt : [INFO     ] 2019-04-15 16:25:25,971 Overriding length_unit: 1 pc.
# yt : [INFO     ] 2019-04-15 16:25:25,971 Overriding time_unit: 1 s*pc/km.
# yt : [INFO     ] 2019-04-15 16:25:25,972 Overriding mass_unit: 2.38859e-24 g/cm**3*pc**3.
# yt : [INFO     ] 2019-04-15 16:25:25,973 Overriding velocity_unit: 1 km/s.
# yt : [INFO     ] 2019-04-15 16:25:25,973 Overriding magnetic_unit: 5.47867e-07 gauss.
# yt : [INFO     ] 2019-04-15 16:25:25,982 Parameters: current_time              = 509.0002
# yt : [INFO     ] 2019-04-15 16:25:25,983 Parameters: domain_dimensions         = [ 256  256 1792]
# yt : [INFO     ] 2019-04-15 16:25:25,983 Parameters: domain_left_edge          = [ -512.  -512. -3584.]
# yt : [INFO     ] 2019-04-15 16:25:25,984 Parameters: domain_right_edge         = [ 512.  512. 3584.]
# yt : [INFO     ] 2019-04-15 16:25:25,984 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2019-04-15 16:28:32,988 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/warm/MHD_4pc_new_mvz.0510.h5.
# yt : [INFO     ] 2019-04-15 16:28:33,055 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/int/MHD_4pc_new_mvz.0510.h5.
# yt : [INFO     ] 2019-04-15 16:28:33,151 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/hot/MHD_4pc_new_mvz.0510.h5.
# yt : [INFO     ] 2019-04-15 16:28:33,406 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2019-04-15 16:28:33,506 Overriding code units: Use this option only if you know that the dataset doesn't define the units correctly or at all.
# yt : [INFO     ] 2019-04-15 16:28:33,507 Overriding length_unit: 1 pc.
# yt : [INFO     ] 2019-04-15 16:28:33,508 Overriding time_unit: 1 s*pc/km.
# yt : [INFO     ] 2019-04-15 16:28:33,508 Overriding mass_unit: 2.38859e-24 g/cm**3*pc**3.
# yt : [INFO     ] 2019-04-15 16:28:33,509 Overriding velocity_unit: 1 km/s.
# yt : [INFO     ] 2019-04-15 16:28:33,510 Overriding magnetic_unit: 5.47867e-07 gauss.
# yt : [INFO     ] 2019-04-15 16:28:33,519 Parameters: current_time              = 510.0005
# yt : [INFO     ] 2019-04-15 16:28:33,519 Parameters: domain_dimensions         = [ 256  256 1792]
# yt : [INFO     ] 2019-04-15 16:28:33,520 Parameters: domain_left_edge          = [ -512.  -512. -3584.]
# yt : [INFO     ] 2019-04-15 16:28:33,521 Parameters: domain_right_edge         = [ 512.  512. 3584.]
# yt : [INFO     ] 2019-04-15 16:28:33,521 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2019-04-15 16:31:42,384 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/warm/MHD_4pc_new_mvz.0511.h5.
# yt : [INFO     ] 2019-04-15 16:31:42,456 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/int/MHD_4pc_new_mvz.0511.h5.
# yt : [INFO     ] 2019-04-15 16:31:42,502 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/hot/MHD_4pc_new_mvz.0511.h5.
# yt : [INFO     ] 2019-04-15 16:31:42,783 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2019-04-15 16:31:42,962 Overriding code units: Use this option only if you know that the dataset doesn't define the units correctly or at all.
# yt : [INFO     ] 2019-04-15 16:31:42,963 Overriding length_unit: 1 pc.
# yt : [INFO     ] 2019-04-15 16:31:42,963 Overriding time_unit: 1 s*pc/km.
# yt : [INFO     ] 2019-04-15 16:31:42,964 Overriding mass_unit: 2.38859e-24 g/cm**3*pc**3.
# yt : [INFO     ] 2019-04-15 16:31:42,965 Overriding velocity_unit: 1 km/s.
# yt : [INFO     ] 2019-04-15 16:31:42,965 Overriding magnetic_unit: 5.47867e-07 gauss.
# yt : [INFO     ] 2019-04-15 16:31:42,975 Parameters: current_time              = 511.0007
# yt : [INFO     ] 2019-04-15 16:31:42,975 Parameters: domain_dimensions         = [ 256  256 1792]
# yt : [INFO     ] 2019-04-15 16:31:42,976 Parameters: domain_left_edge          = [ -512.  -512. -3584.]
# yt : [INFO     ] 2019-04-15 16:31:42,976 Parameters: domain_right_edge         = [ 512.  512. 3584.]
# yt : [INFO     ] 2019-04-15 16:31:42,976 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2019-04-15 16:34:43,252 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/warm/MHD_4pc_new_mvz.0512.h5.
# yt : [INFO     ] 2019-04-15 16:34:43,301 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/int/MHD_4pc_new_mvz.0512.h5.
# yt : [INFO     ] 2019-04-15 16:34:43,365 Saving field data to yt dataset: /tigress/changgoo/MHD_4pc_new/MVZ/hot/MHD_4pc_new_mvz.0512.h5.

# %%
import astropy.constants as c

# %%
import astropy.units as u

# %%
500./(c.pc/(u.km/u.s)).to('Myr')
# Out:
# <Quantity 511.35608253 1 / Myr>
